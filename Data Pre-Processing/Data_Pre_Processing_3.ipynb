# %%
import pandas as pd
import numpy as np

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df1
# Out:
#             Opening  Opening.1                                Title  \
# 0     J A N U A R Y          5              Insidious: The Last Key
# 1     J A N U A R Y          5                     The Strange Ones
# 2     J A N U A R Y         12                         The Commuter
# 3     J A N U A R Y         12                           Proud Mary
# 4     J A N U A R Y         12                     Acts of Violence
# 5     J A N U A R Y         12                           Freak Show
# 6     J A N U A R Y         12                             Humor Me
# 7     J A N U A R Y         19                            12 Strong
# 8     J A N U A R Y         19                       Den of Thieves
# 9     J A N U A R Y         19                      Forever My Girl
# 10    J A N U A R Y         25                 Thane of East County
# 11    J A N U A R Y         26          Maze Runner: The Death Cure
# 12    J A N U A R Y         26                      Please Stand By
# ...

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                    Title  \
# 0      J A N U A R Y          5  Insidious: The Last Key
# 1      J A N U A R Y          5         The Strange Ones
# 2      J A N U A R Y         12             The Commuter
# 3      J A N U A R Y         12               Proud Mary
# 4      J A N U A R Y         12         Acts of Violence
# ..               ...        ...                      ...
# 243  D E C E M B E R         21               Second Act
# 244  D E C E M B E R         25          Holmes & Watson
# 245  D E C E M B E R         25                     Vice
# 246  D E C E M B E R         25      On the Basis of Sex
# 247  D E C E M B E R         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# ...

# %%
pip install tmdbv3api

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '9e7e8763d8a867d76e3180aa764b5e65'

# %%
# getting the genres for our movies dataset

from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x): #pass in the title of the movies
    genres = []
    result = tmdb_movie.search(x) #the title will be searched in the tmdb_movie
    movie_id = result[0].id #we will match the "id" with the "title"
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key)) #we will get the result from the IMDb data using the movie id
    data_json = response.json() #we will then convert it to a json file
    if data_json['genres']: #in the json file we will only need to extract the "genre"
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name']) #we will then add the "genre" to the empty genre list we created above
        return " ".join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df
# Out:
#              Opening  Opening.1                    Title  \
# 0      J A N U A R Y          5  Insidious: The Last Key
# 1      J A N U A R Y          5         The Strange Ones
# 2      J A N U A R Y         12             The Commuter
# 3      J A N U A R Y         12               Proud Mary
# 4      J A N U A R Y         12         Acts of Violence
# ..               ...        ...                      ...
# 243  D E C E M B E R         21               Second Act
# 244  D E C E M B E R         25          Holmes & Watson
# 245  D E C E M B E R         25                     Vice
# 246  D E C E M B E R         25      On the Basis of Sex
# 247  D E C E M B E R         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# ...

# %%
df_2018 = df[['Title', 'Cast and crew', 'genres']]
df_2018.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Christopher Radcliff (director/screenplay); La...
# 2             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
# 3               Proud Mary  Babak Najafi (director); John S. Newman, Chris...
# 4         Acts of Violence  Brett Donowho (director); Nicolas Aaron Mezzan...
#
#                     genres
# 0          Horror Thriller
# 1            Drama Mystery
# 2  Action Thriller Mystery
# 3    Thriller Action Crime
# 4    Action Crime Thriller

# %% [markdown]
# **Extracting Directors**

# %%
import re
def extract_director(cast_and_crew):
    # Regex to capture the name before (director) or variations
    match = re.search(r'([A-Za-z\s\.\-]+)\s*\(director(?:/screenplay)?', cast_and_crew)
    if match:
        return match.group(1).strip()

# %%
df_2018['director_name'] = df_2018['Cast and crew'].apply(extract_director)
# Out:
# <ipython-input-14-5f192db830bd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].apply(extract_director)

# %%
df_2018.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Christopher Radcliff (director/screenplay); La...
# 2             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
# 3               Proud Mary  Babak Najafi (director); John S. Newman, Chris...
# 4         Acts of Violence  Brett Donowho (director); Nicolas Aaron Mezzan...
#
#                     genres         director_name
# 0          Horror Thriller          Adam Robitel
# 1            Drama Mystery  Christopher Radcliff
# 2  Action Thriller Mystery    Jaume Collet-Serra
# 3    Thriller Action Crime          Babak Najafi
# 4    Action Crime Thriller         Brett Donowho

# %% [markdown]
# **Actor 1**

# %%
#df_2018['Cast and crew'].unique()

# %%
def get_actor1(x):
    # Get the initial actor name using screenplay split logic
    initial_actor = (x.split("screenplay); ")[-1]).split(", ")[0]
    # Check if there’s a semicolon in the result
    if ";" in initial_actor:
        # If there is, take the part after the last semicolon
        return initial_actor.split(";")[-1].strip()
    else:
        # Otherwise, return the initial result
        return initial_actor.strip()

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %%
#df_2018['actor_1_name'].unique()

# %%
#def get_actor1(x):
#    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
#df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %% [markdown]
# **Actor 2**

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %% [markdown]
# **Actor 3**

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018.head()
# Out:
#                movie_title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Christopher Radcliff (director/screenplay); La...
# 2             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
# 3               Proud Mary  Babak Najafi (director); John S. Newman, Chris...
# 4         Acts of Violence  Brett Donowho (director); Nicolas Aaron Mezzan...
#
#                     genres         director_name      actor_1_name  \
# 0          Horror Thriller          Adam Robitel         Lin Shaye
# 1            Drama Mystery  Christopher Radcliff     Alex Pettyfer
# 2  Action Thriller Mystery    Jaume Collet-Serra       Liam Neeson
# 3    Thriller Action Crime          Babak Najafi  Taraji P. Henson
# 4    Action Crime Thriller         Brett Donowho      Bruce Willis
#
#              actor_2_name    actor_3_name
# 0           Angus Sampson  Leigh Whannell
# ...

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
df_2018_new = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
df_2018_new['actor_2_name'] = df_2018_new['actor_2_name'].replace(np.nan, 'unknown')
df_2018_new['actor_3_name'] = df_2018_new['actor_3_name'].replace(np.nan, 'unknown')

# %%
df_2018_new['movie_title'] = df_2018_new['movie_title'].str.lower()

# %%
df_2018_new['col_merge'] = df_2018_new['actor_1_name'] + ' ' + df_2018_new['actor_2_name'] + ' '+ df_2018_new['actor_3_name'] + ' '+ df_2018_new['director_name'] +' ' + df_2018_new['genres']
df_2018_new
# Out:
#             director_name      actor_1_name            actor_2_name  \
# 0            Adam Robitel         Lin Shaye           Angus Sampson
# 1    Christopher Radcliff     Alex Pettyfer  James Freedson-Jackson
# 2      Jaume Collet-Serra       Liam Neeson            Vera Farmiga
# 3            Babak Najafi  Taraji P. Henson    Jahi Di'Allo Winston
# 4           Brett Donowho      Bruce Willis             Cole Hauser
# ..                    ...               ...                     ...
# 243           Peter Segal    Jennifer Lopez             Leah Remini
# 244            Etan Cohen      Will Ferrell          John C. Reilly
# 245            Adam McKay    Christian Bale               Amy Adams
# 246            Mimi Leder    Felicity Jones            Armie Hammer
# 247          Karyn Kusama     Nicole Kidman          Sebastian Stan
#
#         actor_3_name                                     genres  \
# 0     Leigh Whannell                            Horror Thriller
# ...

# %% [markdown]
# # **Extracting features of 2019 movies from Wikipedia**

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
df.head()
# Out:
#          Opening Opening.1             Title  \
# 0  J A N U A R Y         4       Escape Room
# 1  J A N U A R Y         4        Rust Creek
# 2  J A N U A R Y         4  American Hangman
# 3  J A N U A R Y        11  A Dog's Way Home
# 4  J A N U A R Y        11        The Upside
#
#                   Production company  \
# 0  Columbia Pictures / Original Film
# 1     IFC Films / Lunacy Productions
# 2        Hangman Justice Productions
# 3                  Columbia Pictures
# 4                  STX Entertainment
#
#                                        Cast and crew Ref.
# 0  Adam Robitel (director); Bragi F. Schut, Maria...  [2]
# 1  Jen McGowan (director); Julie Lipson (screenpl...  [3]
# 2  Wilson Coneybeare (director/screenplay); Donal...  [4]
# 3  Charles Martin Smith (director); W. Bruce Came...  [5]
# 4  Neil Burger (director); Jon Hartmere (screenpl...  [6]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df.head()
# Out:
#          Opening Opening.1             Title  \
# 0  J A N U A R Y         4       Escape Room
# 1  J A N U A R Y         4        Rust Creek
# 2  J A N U A R Y         4  American Hangman
# 3  J A N U A R Y        11  A Dog's Way Home
# 4  J A N U A R Y        11        The Upside
#
#                   Production company  \
# 0  Columbia Pictures / Original Film
# 1     IFC Films / Lunacy Productions
# 2        Hangman Justice Productions
# 3                  Columbia Pictures
# 4                  STX Entertainment
#
#                                        Cast and crew Ref.  \
# 0  Adam Robitel (director); Bragi F. Schut, Maria...  [2]
# 1  Jen McGowan (director); Julie Lipson (screenpl...  [3]
# 2  Wilson Coneybeare (director/screenplay); Donal...  [4]
# 3  Charles Martin Smith (director); W. Bruce Came...  [5]
# 4  Neil Burger (director); Jon Hartmere (screenpl...  [6]
#
#                         genres
# 0      Horror Thriller Mystery
# 1  Thriller Drama Action Crime
# ...

# %%
df_2019 = df[['Title', 'Cast and crew', 'genres']]
df_2019.head()
# Out:
#               Title                                      Cast and crew  \
# 0       Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1        Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2  American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3  A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4        The Upside  Neil Burger (director); Jon Hartmere (screenpl...
#
#                         genres
# 0      Horror Thriller Mystery
# 1  Thriller Drama Action Crime
# 2                     Thriller
# 3       Drama Adventure Family
# 4                 Comedy Drama

# %%
df_2019['director_name'] = df_2019['Cast and crew'].apply(extract_director)
# Out:
# <ipython-input-105-6d34e0bc521d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].apply(extract_director)

# %%
df_2019.head()
# Out:
#               Title                                      Cast and crew  \
# 0       Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1        Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2  American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3  A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4        The Upside  Neil Burger (director); Jon Hartmere (screenpl...
#
#                         genres         director_name
# 0      Horror Thriller Mystery          Adam Robitel
# 1  Thriller Drama Action Crime           Jen McGowan
# 2                     Thriller     Wilson Coneybeare
# 3       Drama Adventure Family  Charles Martin Smith
# 4                 Comedy Drama           Neil Burger

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-107-eee71c5586b8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-108-48d0aadc78c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019
# Out:
#                  Title                                      Cast and crew  \
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 245  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 246       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 247               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 248         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 249           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                        genres          director_name  \
# ...

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
df_2019_new = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
df_2019_new['actor_2_name'] = df_2019_new['actor_2_name'].replace(np.nan, 'unknown')
df_2019_new['actor_3_name'] = df_2019_new['actor_3_name'].replace(np.nan, 'unknown')

# %%
df_2019_new['movie_title'] = df_2019_new['movie_title'].str.lower()

# %%
df_2019_new['col_merge'] = df_2019_new['actor_1_name'] + ' ' + df_2019_new['actor_2_name'] + ' '+ df_2019_new['actor_3_name'] + ' '+ df_2019_new['director_name'] +' ' + df_2019_new['genres']
df_2019_new.head()
# Out:
#           director_name         actor_1_name        actor_2_name  \
# 0          Adam Robitel       Taylor Russell        Logan Miller
# 1           Jen McGowan    Hermione Corfield         Jay Paulson
# 2     Wilson Coneybeare    Donald Sutherland  Vincent Kartheiser
# 3  Charles Martin Smith  Bryce Dallas Howard  Edward James Olmos
# 4           Neil Burger       Bryan Cranston          Kevin Hart
#
#        actor_3_name                       genres       movie_title  \
# 0  Deborah Ann Woll      Horror Thriller Mystery       escape room
# 1      Sean O'Bryan  Thriller Drama Action Crime        rust creek
# 2     Oliver Dennis                     Thriller  american hangman
# 3   Alexandra Shipp       Drama Adventure Family  a dog's way home
# 4     Nicole Kidman                 Comedy Drama        the upside
#
#                                            col_merge
# 0  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# ...

# %%
my_df = pd.concat([df_2018_new, df_2019_new], ignore_index=True)

# %%
my_df
# Out:
#              director_name       actor_1_name            actor_2_name  \
# 0             Adam Robitel          Lin Shaye           Angus Sampson
# 1     Christopher Radcliff      Alex Pettyfer  James Freedson-Jackson
# 2       Jaume Collet-Serra        Liam Neeson            Vera Farmiga
# 3             Babak Najafi   Taraji P. Henson    Jahi Di'Allo Winston
# 4            Brett Donowho       Bruce Willis             Cole Hauser
# ..                     ...                ...                     ...
# 493             Troy Quane         Will Smith             Tom Holland
# 494           Greta Gerwig      Saoirse Ronan             Emma Watson
# 495             Sam Mendes      George MacKay    Dean-Charles Chapman
# 496  Destin Daniel Cretton  Michael B. Jordan              Jamie Foxx
# 497        Chinonye Chukwu      Alfre Woodard          Wendell Pierce
#
#        actor_3_name                                    genres  \
# 0    Leigh Whannell                           Horror Thriller
# ...

# %%
data2 = pd.read_csv('/content/data2.csv')
data2
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# ...

# %%
data_till_2019 = pd.concat([my_df, data2], ignore_index=True)
data_till_2019
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0              Adam Robitel             Lin Shaye           Angus Sampson
# 1      Christopher Radcliff         Alex Pettyfer  James Freedson-Jackson
# 2        Jaume Collet-Serra           Liam Neeson            Vera Farmiga
# 3              Babak Najafi      Taraji P. Henson    Jahi Di'Allo Winston
# 4             Brett Donowho          Bruce Willis             Cole Hauser
# ...                     ...                   ...                     ...
# 5857            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5858            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5859       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5860  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5861           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#            actor_3_name                      genres  \
# ...

# %%
data_till_2019.isna().sum()
# Out:
# director_name    1
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# col_merge        1
# dtype: int64

# %%
data_till_2019 = data_till_2019.dropna(how='any')

# %%
data_till_2019.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# col_merge        0
# dtype: int64

# %%
data_till_2019.to_csv('data_till_2019.csv', index=False)

# %%
import requests
import bs4 as bs
import urllib.request

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
# df1 = pd.read_html(str(tables[0]))[0]
# df2 = pd.read_html(str(tables[1]))[0]
# df3 = pd.read_html(str(tables[2]))[0]
# df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df1
# Out:
#             Opening  Opening.1  \
# 0     J A N U A R Y          3
# 1     J A N U A R Y         10
# 2     J A N U A R Y         10
# 3     J A N U A R Y         10
# 4     J A N U A R Y         10
# 5     J A N U A R Y         10
# 6     J A N U A R Y         10
# 7     J A N U A R Y         14
# 8     J A N U A R Y         17
# 9     J A N U A R Y         17
# 10    J A N U A R Y         17
# 11    J A N U A R Y         24
# 12    J A N U A R Y         24
# 13    J A N U A R Y         24
# 14    J A N U A R Y         24
# 15    J A N U A R Y         31
# 16    J A N U A R Y         31
# 17    J A N U A R Y         31
# 18  F E B R U A R Y          7
# 19  F E B R U A R Y          7
# 20  F E B R U A R Y          7
# 21  F E B R U A R Y          7
# 22  F E B R U A R Y         12
# 23  F E B R U A R Y         14
# 24  F E B R U A R Y         14
# 25  F E B R U A R Y         14
# 26  F E B R U A R Y         14
# 27  F E B R U A R Y         14
# 28  F E B R U A R Y         14
# ...

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                  Title  \
# 0      J A N U A R Y          3             The Grudge
# 1      J A N U A R Y         10             Underwater
# 2      J A N U A R Y         10            Like a Boss
# 3      J A N U A R Y         10          Three Christs
# 4      J A N U A R Y         10      Inherit the Viper
# ..               ...        ...                    ...
# 271  D E C E M B E R         25       We Can Be Heroes
# 272  D E C E M B E R         25      News of the World
# 273  D E C E M B E R         25  One Night in Miami...
# 274  D E C E M B E R         25  Promising Young Woman
# 275  D E C E M B E R         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                   Paramount Pictures / Artists First
# 3                                            IFC Films
# ...

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020.head()
# Out:
#                Title                                      Cast and crew
# 0         The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1         Underwater  William Eubank (director); Brian Duffield, Ada...
# 2        Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3      Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4  Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...

# %%
tmdb_movie = Movie()
# def get_genre(x):
#     genres = []
#     result = tmdb_movie.search(x)
#     if not result:
#       return np.NaN
#     else:
#       movie_id = result[0]["id"]
#       response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
#       data_json = response.json()
#       if data_json.get('genres'):
#           for genre in data_json['genres']:
#             genres.append(genre['name'])
#           return " ".join(genres)
#       else:
#           return np.NaN

def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)

    # Debugging: Print the result to inspect its structure
    #print("Search result for '{}':".format(x), result)

    # Check if result is empty
    if not result:
        return np.NaN

    # Access the id based on the structure of result[0]
    try:
      #Access the id directly as it's a dictionary
        movie_id = result[0]["id"]
    except (IndexError, TypeError, KeyError) as e:
        print(f"Error accessing movie ID for title '{x}':", e)
        return np.NaN

    # Fetch genre data from the API
    response = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb.api_key}')
    data_json = response.json()

    if data_json.get('genres'):
        for genre in data_json['genres']:
            genres.append(genre['name'])
        return " ".join(genres)
    else:
        return np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2020['director_name'] = df_2020['Cast and crew'].apply(extract_director)
# Out:
# <ipython-input-171-dba14aa0c8d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].apply(extract_director)

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-173-da3b02104b70>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(x))

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(x))

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2020.head()
# Out:
#                Title                                      Cast and crew  \
# 0         The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1         Underwater  William Eubank (director); Brian Duffield, Ada...
# 2        Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3      Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4  Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
#
#                                     genres   director_name  \
# 0                  Horror Mystery Thriller   Nicolas Pesce
# 1  Horror Science Fiction Action Adventure  William Eubank
# 2                                   Comedy   Miguel Arteta
# 3                                    Drama       Jon Avnet
# 4                     Crime Thriller Drama  Anthony Jerjen
#
#          actor_1_name       actor_2_name     actor_3_name
# 0  Andrea Riseborough      Demián Bichir         John Cho
# 1     Kristen Stewart     Vincent Cassel  Jessica Henwick
# ...

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
df_2020_new = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
df_2020_new['movie_title'] = df_2020_new['movie_title'].str.lower()

# %%
df_2020_new['col_merge'] = df_2020_new['actor_1_name'] + ' ' + df_2020_new['actor_2_name'] + ' '+ df_2020_new['actor_3_name'] + ' '+ df_2020_new['director_name'] +' ' + df_2020_new['genres']
df_2020_new.head()
# Out:
#     director_name        actor_1_name       actor_2_name     actor_3_name  \
# 0   Nicolas Pesce  Andrea Riseborough      Demián Bichir         John Cho
# 1  William Eubank     Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2   Miguel Arteta     Tiffany Haddish         Rose Byrne      Salma Hayek
# 3       Jon Avnet        Richard Gere     Peter Dinklage   Walton Goggins
# 4  Anthony Jerjen       Josh Hartnett  Margarita Levieva   Chandler Riggs
#
#                                     genres        movie_title  \
# 0                  Horror Mystery Thriller         the grudge
# 1  Horror Science Fiction Action Adventure         underwater
# 2                                   Comedy        like a boss
# 3                                    Drama      three christs
# 4                     Crime Thriller Drama  inherit the viper
#
#                                            col_merge
# 0  Andrea Riseborough Demián Bichir John Cho Nico...
# ...

# %%
df_2020_new.isna().sum()
# Out:
# director_name     1
# actor_1_name      0
# actor_2_name      5
# actor_3_name     28
# genres            2
# movie_title       0
# col_merge        29
# dtype: int64

# %%
df_2020_new = df_2020_new.dropna(how='any')

# %%
df_2020_new.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# col_merge        0
# dtype: int64

# %%
data_till_2020 = pd.concat([data_till_2019, df_2020_new], ignore_index=True)

# %%
data_till_2020.to_csv('data_till_2020.csv', index=False)
