# %% [markdown]
# # **Extracting features of 2021 movies from Wikipedia**

# %%
import pandas as pd
import numpy as np

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                            Title  \
# 0      J A N U A R Y        1.0              Shadow in the Cloud
# 1      J A N U A R Y        5.0                          Hacksaw
# 2      J A N U A R Y       12.0  Dr. Bird's Advice for Sad Poets
# 3      J A N U A R Y       13.0                  The White Tiger
# 4      J A N U A R Y       14.0                      Locked Down
# ..               ...        ...                              ...
# 361  D E C E M B E R       25.0           The Tragedy of Macbeth
# 362  D E C E M B E R       25.0             A Journal for Jordan
# 363  D E C E M B E R       25.0                American Underdog
# 364  D E C E M B E R       26.0                          Memoria
# 365  D E C E M B E R        NaN                              NaN
#
#                                     Production company  \
# 0                               Vertical Entertainment
# 1                     Leone Films / Midnight Releasing
# 2             Relativity Media / Ketchup Entertainment
# 3             Netflix / ARRAY / Purple Pebble Pictures
# 4                      HBO Max / Warner Bros. Pictures
# ..                                                 ...
# 361                        Apple TV+ / A24 / IAC Films
# 362  Columbia Pictures / Escape Artists / Bron Studios
# 363                                          Lionsgate
# 364                                               Neon
# 365                                                NaN
#
#                                          Cast and crew   Ref.
# 0    Roseanne Liang (director/screenplay); Max Land...    [2]
# 1    Anthony Leone (director/screenplay); Amy Cay, ...    [3]
# 2    Yaniv Raz (director/screenplay); Lucas Jade Zu...    [4]
# 3    Ramin Bahrani (director/screenplay); Adarsh Go...    NaN
# 4    Doug Liman (director); Steven Knight (screenpl...    [5]
# ..                                                 ...    ...
# 361  Joel Coen (director/screenplay); Denzel Washin...  [278]
# 362  Denzel Washington (director); Virgil Williams ...  [279]
# 363  Erwin brothers (directors); Jon Erwin, David A...  [280]
# 364  Apichatpong Weerasethakul (director/acreenplay...  [281]
# 365                                                NaN    NaN
#
# [366 rows x 6 columns]

# %%
pip install tmdbv3api
# Out:
# Collecting tmdbv3api
#   Downloading tmdbv3api-1.9.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tmdbv3api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (2024.8.30)
# Downloading tmdbv3api-1.9.0-py3-none-any.whl (25 kB)
# Installing collected packages: tmdbv3api
# Successfully installed tmdbv3api-1.9.0

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '9e7e8763d8a867d76e3180aa764b5e65'

# %%
# getting the genres for our movies dataset

from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)

    # Debugging: Print the result to inspect its structure
    #print("Search result for '{}':".format(x), result)

    # Check if result is empty
    if not result:
        return np.NaN

    # Access the id based on the structure of result[0]
    try:
      #Access the id directly as it's a dictionary
        movie_id = result[0]["id"]
    except (IndexError, TypeError, KeyError) as e:
        print(f"Error accessing movie ID for title '{x}':", e)
        return np.NaN

    # Fetch genre data from the API
    response = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb.api_key}')
    data_json = response.json()

    if data_json.get('genres'):
        for genre in data_json['genres']:
            genres.append(genre['name'])
        return " ".join(genres)
    else:
        return np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df
# Out:
# Error accessing movie ID for title 'Dating and New York': getattr(): attribute name must be string
#              Opening  Opening.1                            Title  \
# 0      J A N U A R Y        1.0              Shadow in the Cloud
# 1      J A N U A R Y        5.0                          Hacksaw
# 2      J A N U A R Y       12.0  Dr. Bird's Advice for Sad Poets
# 3      J A N U A R Y       13.0                  The White Tiger
# 4      J A N U A R Y       14.0                      Locked Down
# ..               ...        ...                              ...
# 361  D E C E M B E R       25.0           The Tragedy of Macbeth
# 362  D E C E M B E R       25.0             A Journal for Jordan
# 363  D E C E M B E R       25.0                American Underdog
# 364  D E C E M B E R       26.0                          Memoria
# 365  D E C E M B E R        NaN                              NaN
#
#                                     Production company  \
# 0                               Vertical Entertainment
# 1                     Leone Films / Midnight Releasing
# 2             Relativity Media / Ketchup Entertainment
# 3             Netflix / ARRAY / Purple Pebble Pictures
# 4                      HBO Max / Warner Bros. Pictures
# ..                                                 ...
# 361                        Apple TV+ / A24 / IAC Films
# 362  Columbia Pictures / Escape Artists / Bron Studios
# 363                                          Lionsgate
# 364                                               Neon
# 365                                                NaN
#
#                                          Cast and crew   Ref.  \
# 0    Roseanne Liang (director/screenplay); Max Land...    [2]
# 1    Anthony Leone (director/screenplay); Amy Cay, ...    [3]
# 2    Yaniv Raz (director/screenplay); Lucas Jade Zu...    [4]
# 3    Ramin Bahrani (director/screenplay); Adarsh Go...    NaN
# 4    Doug Liman (director); Steven Knight (screenpl...    [5]
# ..                                                 ...    ...
# 361  Joel Coen (director/screenplay); Denzel Washin...  [278]
# 362  Denzel Washington (director); Virgil Williams ...  [279]
# 363  Erwin brothers (directors); Jon Erwin, David A...  [280]
# 364  Apichatpong Weerasethakul (director/acreenplay...  [281]
# 365                                                NaN    NaN
#
#                                 genres
# 0                    Horror Action War
# 1    Adventure Family TV Movie Western
# 2                         Comedy Drama
# 3                                Drama
# 4                 Comedy Crime Romance
# ..                                 ...
# 361                          Drama War
# 362                      Drama Romance
# 363                       Drama Family
# 364      Drama Science Fiction Mystery
# 365                        Drama Crime
#
# [366 rows x 7 columns]

# %%
df_2021 = df[['Title', 'Cast and crew', 'genres']]
df_2021.head()
# Out:
#                              Title  \
# 0              Shadow in the Cloud
# 1                          Hacksaw
# 2  Dr. Bird's Advice for Sad Poets
# 3                  The White Tiger
# 4                      Locked Down
#
#                                        Cast and crew  \
# 0  Roseanne Liang (director/screenplay); Max Land...
# 1  Anthony Leone (director/screenplay); Amy Cay, ...
# 2  Yaniv Raz (director/screenplay); Lucas Jade Zu...
# 3  Ramin Bahrani (director/screenplay); Adarsh Go...
# 4  Doug Liman (director); Steven Knight (screenpl...
#
#                               genres
# 0                  Horror Action War
# 1  Adventure Family TV Movie Western
# 2                       Comedy Drama
# 3                              Drama
# 4               Comedy Crime Romance

# %% [markdown]
# **Extracting Directors**

# %%
import re
def extract_director(cast_and_crew):
    # Regex to capture the name before (director) or variations
    match = re.search(r'([A-Za-z\s\.\-]+)\s*\(director(?:/screenplay)?', cast_and_crew)
    if match:
        return match.group(1).strip()

# %%
df_2021
# Out:
#                                Title  \
# 0                Shadow in the Cloud
# 1                            Hacksaw
# 2    Dr. Bird's Advice for Sad Poets
# 3                    The White Tiger
# 4                        Locked Down
# ..                               ...
# 361           The Tragedy of Macbeth
# 362             A Journal for Jordan
# 363                American Underdog
# 364                          Memoria
# 365                              NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Anthony Leone (director/screenplay); Amy Cay, ...
# 2    Yaniv Raz (director/screenplay); Lucas Jade Zu...
# 3    Ramin Bahrani (director/screenplay); Adarsh Go...
# 4    Doug Liman (director); Steven Knight (screenpl...
# ..                                                 ...
# 361  Joel Coen (director/screenplay); Denzel Washin...
# 362  Denzel Washington (director); Virgil Williams ...
# 363  Erwin brothers (directors); Jon Erwin, David A...
# 364  Apichatpong Weerasethakul (director/acreenplay...
# 365                                                NaN
#
#                                 genres
# 0                    Horror Action War
# 1    Adventure Family TV Movie Western
# 2                         Comedy Drama
# 3                                Drama
# 4                 Comedy Crime Romance
# ..                                 ...
# 361                          Drama War
# 362                      Drama Romance
# 363                       Drama Family
# 364      Drama Science Fiction Mystery
# 365                        Drama Crime
#
# [366 rows x 3 columns]

# %%
df_2021 = df_2021[:-1]

# %%
df_2021['director_name'] = df_2021['Cast and crew'].apply(extract_director)
# Out:
# <ipython-input-18-934e263d899d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['director_name'] = df_2021['Cast and crew'].apply(extract_director)

# %% [markdown]
# **Extracting Actor 1 Name**

# %%
def get_actor1(x):
    # Get the initial actor name using screenplay split logic
    initial_actor = (x.split("screenplay); ")[-1]).split(", ")[0]
    # Check if there’s a semicolon in the result
    if ";" in initial_actor:
        # If there is, take the part after the last semicolon
        return initial_actor.split(";")[-1].strip()
    else:
        # Otherwise, return the initial result
        return initial_actor.strip()

# %%
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-21-bf0437ae2187>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(x))

# %% [markdown]
# **Extracting Actor 2 Name**

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-23-64783237bae2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(x))

# %% [markdown]
# **Extracting Actor 3 Name**

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# <ipython-input-25-979f1e440eff>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
df_2021_new = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
df_2021_new['actor_2_name'] = df_2021_new['actor_2_name'].replace(np.nan, 'unknown')
df_2021_new['actor_3_name'] = df_2021_new['actor_3_name'].replace(np.nan, 'unknown')

# %%
df_2021_new['movie_title'] = df_2021_new['movie_title'].str.lower()

# %%
df_2021_new['col_merge'] = df_2021_new['actor_1_name'] + ' ' + df_2021_new['actor_2_name'] + ' '+ df_2021_new['actor_3_name'] + ' '+ df_2021_new['director_name'] +' ' + df_2021_new['genres']
df_2021_new
# Out:
#                  director_name        actor_1_name          actor_2_name  \
# 0               Roseanne Liang  Chloë Grace Moretz     Taylor John Smith
# 1                Anthony Leone             Amy Cay  Brian Patrick Butler
# 2                    Yaniv Raz   Lucas Jade Zumann        Taylor Russell
# 3                Ramin Bahrani       Adarsh Gourav         Rajkummar Rao
# 4                   Doug Liman       Anne Hathaway      Chiwetel Ejiofor
# ..                         ...                 ...                   ...
# 360             Matthew Vaughn       Ralph Fiennes        Gemma Arterton
# 361                  Joel Coen   Denzel Washington     Frances McDormand
# 362          Denzel Washington   Michael B. Jordan          Chanté Adams
# 363             Erwin brothers        Zachary Levi           Anna Paquin
# 364  Apichatpong Weerasethakul       Tilda Swinton            Elkin Díaz
#
#               actor_3_name                             genres  \
# 0             Beulah Koale                  Horror Action War
# 1       Michael C. Burgess  Adventure Family TV Movie Western
# 2             Chase Stokes                       Comedy Drama
# 3    Priyanka Chopra Jonas                              Drama
# 4         Stephen Merchant               Comedy Crime Romance
# ..                     ...                                ...
# 360             Rhys Ifans          Action Adventure Thriller
# 361          Bertie Carvel                          Drama War
# 362        Jalon Christian                      Drama Romance
# 363           Dennis Quaid                       Drama Family
# 364         Jeanne Balibar      Drama Science Fiction Mystery
#
#                          movie_title  \
# 0                shadow in the cloud
# 1                            hacksaw
# 2    dr. bird's advice for sad poets
# 3                    the white tiger
# 4                        locked down
# ..                               ...
# 360                   the king's man
# 361           the tragedy of macbeth
# 362             a journal for jordan
# 363                american underdog
# 364                          memoria
#
#                                              col_merge
# 0    Chloë Grace Moretz Taylor John Smith Beulah Ko...
# 1    Amy Cay Brian Patrick Butler Michael C. Burges...
# 2    Lucas Jade Zumann Taylor Russell Chase Stokes ...
# 3    Adarsh Gourav Rajkummar Rao Priyanka Chopra Jo...
# 4    Anne Hathaway Chiwetel Ejiofor Stephen Merchan...
# ..                                                 ...
# 360  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 361  Denzel Washington Frances McDormand Bertie Car...
# 362  Michael B. Jordan Chanté Adams Jalon Christian...
# 363  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 364  Tilda Swinton Elkin Díaz Jeanne Balibar Apicha...
#
# [365 rows x 7 columns]

# %% [markdown]
# # **Extracting features of 2022 movies from Wikipedia**

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
#df = df[:-4]

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                                         Title  \
# 0      J A N U A R Y        7.0                                       The 355
# 1      J A N U A R Y        7.0                      The Legend of La Llorona
# 2      J A N U A R Y        7.0                                  The Commando
# 3      J A N U A R Y        7.0                                American Siege
# 4      J A N U A R Y       14.0                                        Scream
# ..               ...        ...                                           ...
# 312  D E C E M B E R       23.0  Whitney Houston: I Wanna Dance with Somebody
# 313  D E C E M B E R       23.0                             The Pale Blue Eye
# 314  D E C E M B E R       23.0                                 Women Talking
# 315  D E C E M B E R       29.0                             A Man Called Otto
# 316  D E C E M B E R       30.0                                Alice, Darling
#
#                                     Production company  \
# 0    Universal Pictures / Freckle Films / FilmNatio...
# 1                       Saban Films / Ageless Pictures
# 2                 Saban Films / Premiere Entertainment
# 3                               Vertical Entertainment
# 4    Paramount Pictures / Spyglass Media Group / Ra...
# ..                                                 ...
# 312               TriStar Pictures / Black Label Media
# 313                     Netflix / Cross Creek Pictures
# 314              Orion Pictures / Plan B Entertainment
# 315  Columbia Pictures / Stage 6 Films / Playtone /...
# 316                     Lionsgate / Elevation Pictures
#
#                                          Cast and crew   Ref.
# 0    Simon Kinberg (director/screenplay); Theresa R...    [2]
# 1    Patricia Harris Seeley (director); José Prende...    [3]
# 2    Asif Akbar (director); Koji Steven Sakai (scre...    [4]
# 3    Edward John Drake (director/screenplay); Timot...    [5]
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...    [6]
# ..                                                 ...    ...
# 312  Kasi Lemmons (director); Anthony McCarten (scr...   [56]
# 313  Scott Cooper (director/screenplay); Christian ...  [183]
# 314  Sarah Polley (director/screenplay); Rooney Mar...  [263]
# 315  Marc Forster (director), David Magee (screenpl...  [264]
# 316  Mary Nighy (director); Alanna Francis (screenp...  [265]
#
# [317 rows x 6 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df
# Out:
# Error accessing movie ID for title 'Apollo 10 1⁄2: A Space Age Childhood': getattr(): attribute name must be string
# <ipython-input-39-acffb7f90574>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
#              Opening  Opening.1                                         Title  \
# 0      J A N U A R Y        7.0                                       The 355
# 1      J A N U A R Y        7.0                      The Legend of La Llorona
# 2      J A N U A R Y        7.0                                  The Commando
# 3      J A N U A R Y        7.0                                American Siege
# 4      J A N U A R Y       14.0                                        Scream
# ..               ...        ...                                           ...
# 312  D E C E M B E R       23.0  Whitney Houston: I Wanna Dance with Somebody
# 313  D E C E M B E R       23.0                             The Pale Blue Eye
# 314  D E C E M B E R       23.0                                 Women Talking
# 315  D E C E M B E R       29.0                             A Man Called Otto
# 316  D E C E M B E R       30.0                                Alice, Darling
#
#                                     Production company  \
# 0    Universal Pictures / Freckle Films / FilmNatio...
# 1                       Saban Films / Ageless Pictures
# 2                 Saban Films / Premiere Entertainment
# 3                               Vertical Entertainment
# 4    Paramount Pictures / Spyglass Media Group / Ra...
# ..                                                 ...
# 312               TriStar Pictures / Black Label Media
# 313                     Netflix / Cross Creek Pictures
# 314              Orion Pictures / Plan B Entertainment
# 315  Columbia Pictures / Stage 6 Films / Playtone /...
# 316                     Lionsgate / Elevation Pictures
#
#                                          Cast and crew   Ref.  \
# 0    Simon Kinberg (director/screenplay); Theresa R...    [2]
# 1    Patricia Harris Seeley (director); José Prende...    [3]
# 2    Asif Akbar (director); Koji Steven Sakai (scre...    [4]
# 3    Edward John Drake (director/screenplay); Timot...    [5]
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...    [6]
# ..                                                 ...    ...
# 312  Kasi Lemmons (director); Anthony McCarten (scr...   [56]
# 313  Scott Cooper (director/screenplay); Christian ...  [183]
# 314  Sarah Polley (director/screenplay); Rooney Mar...  [263]
# 315  Marc Forster (director), David Magee (screenpl...  [264]
# 316  Mary Nighy (director); Alanna Francis (screenp...  [265]
#
#                               genres
# 0          Action Adventure Thriller
# 1    Family Animation Fantasy Horror
# 2              Action Crime Thriller
# 3          Action Adventure Thriller
# 4               Crime Horror Mystery
# ..                               ...
# 312              Music History Drama
# 313    Thriller Crime Horror Mystery
# 314                            Drama
# 315                     Comedy Drama
# 316           Thriller Drama Romance
#
# [317 rows x 7 columns]

# %%
df_2022 = df[['Title', 'Cast and crew', 'genres']]
df_2022.head()
# Out:
#                       Title  \
# 0                   The 355
# 1  The Legend of La Llorona
# 2              The Commando
# 3            American Siege
# 4                    Scream
#
#                                        Cast and crew  \
# 0  Simon Kinberg (director/screenplay); Theresa R...
# 1  Patricia Harris Seeley (director); José Prende...
# 2  Asif Akbar (director); Koji Steven Sakai (scre...
# 3  Edward John Drake (director/screenplay); Timot...
# 4  Matt Bettinelli-Olpin, Tyler Gillett (director...
#
#                             genres
# 0        Action Adventure Thriller
# 1  Family Animation Fantasy Horror
# 2            Action Crime Thriller
# 3        Action Adventure Thriller
# 4             Crime Horror Mystery

# %%
df_2022['director_name'] = df_2022['Cast and crew'].apply(extract_director)
# Out:
# <ipython-input-43-38ec34ae6db6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['director_name'] = df_2022['Cast and crew'].apply(extract_director)

# %%
df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-44-c107d38851f7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(x))

# %%
df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-45-da18e330aae0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(x))

# %%
df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3(x))

# %%
#df_2022

# %%
df_2022 = df_2022.rename(columns={'Title':'movie_title'})

# %%
df_2022_new = df_2022.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
df_2022_new['actor_2_name'] = df_2022_new['actor_2_name'].replace(np.nan, 'unknown')
df_2022_new['actor_3_name'] = df_2022_new['actor_3_name'].replace(np.nan, 'unknown')

# %%
df_2022_new['movie_title'] = df_2022_new['movie_title'].str.lower()

# %%
df_2022_new['col_merge'] = df_2022_new['actor_1_name'] + ' ' + df_2022_new['actor_2_name'] + ' '+ df_2022_new['actor_3_name'] + ' '+ df_2022_new['director_name'] +' ' + df_2022_new['genres']
df_2022_new.head()
# Out:
#             director_name       actor_1_name       actor_2_name  actor_3_name  \
# 0           Simon Kinberg   Jessica Chastain      Penélope Cruz  Fan Bingbing
# 1  Patricia Harris Seeley      Autumn Reeser        Danny Trejo  Antonio Cupo
# 2              Asif Akbar      Mickey Rourke  Michael Jai White       unknown
# 3       Edward John Drake  Timothy V. Murphy       Bruce Willis     Rob Gough
# 4           Tyler Gillett    Melissa Barrera      Mason Gooding  Jenna Ortega
#
#                             genres               movie_title  \
# 0        Action Adventure Thriller                   the 355
# 1  Family Animation Fantasy Horror  the legend of la llorona
# 2            Action Crime Thriller              the commando
# 3        Action Adventure Thriller            american siege
# 4             Crime Horror Mystery                    scream
#
#                                            col_merge
# 0  Jessica Chastain Penélope Cruz Fan Bingbing Si...
# 1  Autumn Reeser Danny Trejo Antonio Cupo Patrici...
# 2  Mickey Rourke Michael Jai White unknown Asif A...
# 3  Timothy V. Murphy Bruce Willis Rob Gough Edwar...
# 4  Melissa Barrera Mason Gooding Jenna Ortega Tyl...

# %%
my_df = pd.concat([df_2021_new, df_2022_new], ignore_index=True)

# %%
my_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           2
# movie_title      0
# col_merge        2
# dtype: int64

# %%
my_df = my_df.dropna(how='any')

# %%
data_till_2020 = pd.read_csv('/content/data_till_2020.csv')
data_till_2020
# Out:
#              director_name           actor_1_name            actor_2_name  \
# 0             Adam Robitel              Lin Shaye           Angus Sampson
# 1     Christopher Radcliff          Alex Pettyfer  James Freedson-Jackson
# 2       Jaume Collet-Serra            Liam Neeson            Vera Farmiga
# 3             Babak Najafi       Taraji P. Henson    Jahi Di'Allo Winston
# 4            Brett Donowho           Bruce Willis             Cole Hauser
# ...                    ...                    ...                     ...
# 6103           Pete Docter             Jamie Foxx                Tina Fey
# 6104      Robert Rodriguez  Priyanka Chopra Jonas            Pedro Pascal
# 6105           Regina King      Kingsley Ben-Adir               Eli Goree
# 6106       Emerald Fennell         Carey Mulligan              Bo Burnham
# 6107                   NaN          Vanessa Kirby            Shia LaBeouf
#
#         actor_3_name                           genres  \
# 0     Leigh Whannell                  Horror Thriller
# 1      Emily Althaus                    Drama Mystery
# 2     Patrick Wilson          Action Thriller Mystery
# 3        Billy Brown            Thriller Action Crime
# 4      Shawn Ashmore            Action Crime Thriller
# ...              ...                              ...
# 6103   Graham Norton  Animation Family Comedy Fantasy
# 6104   YaYa Gosselin     Family Action Fantasy Comedy
# 6105     Aldis Hodge                            Drama
# 6106     Alison Brie             Thriller Crime Drama
# 6107    Molly Parker                            Drama
#
#                   movie_title  \
# 0     insidious: the last key
# 1            the strange ones
# 2                the commuter
# 3                  proud mary
# 4            acts of violence
# ...                       ...
# 6103                     soul
# 6104         we can be heroes
# 6105    one night in miami...
# 6106    promising young woman
# 6107        pieces of a woman
#
#                                               col_merge
# 0     Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1     Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2     Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# 3     Taraji P. Henson Jahi Di'Allo Winston Billy Br...
# 4     Bruce Willis Cole Hauser Shawn Ashmore Brett D...
# ...                                                 ...
# 6103  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 6104  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 6105  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 6106  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 6107     Vanessa Kirby Shia LaBeouf Molly Parker  Drama
#
# [6108 rows x 7 columns]

# %%
data_till_2022 = pd.concat([my_df, data_till_2020], ignore_index=True)
#data_till_2022
# Out:
#          director_name           actor_1_name          actor_2_name  \
# 0       Roseanne Liang     Chloë Grace Moretz     Taylor John Smith
# 1        Anthony Leone                Amy Cay  Brian Patrick Butler
# 2            Yaniv Raz      Lucas Jade Zumann        Taylor Russell
# 3        Ramin Bahrani          Adarsh Gourav         Rajkummar Rao
# 4           Doug Liman          Anne Hathaway      Chiwetel Ejiofor
# ...                ...                    ...                   ...
# 6783       Pete Docter             Jamie Foxx              Tina Fey
# 6784  Robert Rodriguez  Priyanka Chopra Jonas          Pedro Pascal
# 6785       Regina King      Kingsley Ben-Adir             Eli Goree
# 6786   Emerald Fennell         Carey Mulligan            Bo Burnham
# 6787               NaN          Vanessa Kirby          Shia LaBeouf
#
#                actor_3_name                             genres  \
# 0              Beulah Koale                  Horror Action War
# 1        Michael C. Burgess  Adventure Family TV Movie Western
# 2              Chase Stokes                       Comedy Drama
# 3     Priyanka Chopra Jonas                              Drama
# 4          Stephen Merchant               Comedy Crime Romance
# ...                     ...                                ...
# 6783          Graham Norton    Animation Family Comedy Fantasy
# 6784          YaYa Gosselin       Family Action Fantasy Comedy
# 6785            Aldis Hodge                              Drama
# 6786            Alison Brie               Thriller Crime Drama
# 6787           Molly Parker                              Drama
#
#                           movie_title  \
# 0                 shadow in the cloud
# 1                             hacksaw
# 2     dr. bird's advice for sad poets
# 3                     the white tiger
# 4                         locked down
# ...                               ...
# 6783                             soul
# 6784                 we can be heroes
# 6785            one night in miami...
# 6786            promising young woman
# 6787                pieces of a woman
#
#                                               col_merge
# 0     Chloë Grace Moretz Taylor John Smith Beulah Ko...
# 1     Amy Cay Brian Patrick Butler Michael C. Burges...
# 2     Lucas Jade Zumann Taylor Russell Chase Stokes ...
# 3     Adarsh Gourav Rajkummar Rao Priyanka Chopra Jo...
# 4     Anne Hathaway Chiwetel Ejiofor Stephen Merchan...
# ...                                                 ...
# 6783  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 6784  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 6785  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 6786  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 6787     Vanessa Kirby Shia LaBeouf Molly Parker  Drama
#
# [6788 rows x 7 columns]

# %%
data_till_2022.isna().sum()
# Out:
# director_name    2
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# col_merge        0
# dtype: int64

# %%
data_till_2022 = data_till_2022.dropna(how='any')

# %%
data_till_2022.to_csv('data_till_2022.csv', index=False)

# %% [markdown]
# # **Extracting features of 2023 movies from Wikipedia**

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2023"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
df.head()
# Out:
#          Opening  Opening.1                 Title  \
# 0  J A N U A R Y          6                 M3GAN
# 1  J A N U A R Y          6           The Old Way
# 2  J A N U A R Y         11  The Devil Conspiracy
# 3  J A N U A R Y         13                 Plane
# 4  J A N U A R Y         13           House Party
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / A...
# 1                         Saban Films / Saturn Films
# 2                               Samuel Goldwyn Films
# 3  Lionsgate / MadRiver Pictures / Di Bonaventura...
# 4            Warner Bros. Pictures / New Line Cinema
#
#                                        Cast and crew Ref.
# 0  Gerard Johnstone (director); Akela Cooper (scr...  [3]
# 1  Brett Donowho (director); Carl W. Lucas (scree...  [4]
# 2  Nathan Frankowski (director); Ed Alan (screenp...  [5]
# 3  Jean-François Richet (director); Charles Cummi...  [6]
# 4  Calmatic (director); Jamal Olori, Stephen Glov...  [7]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df.head()
# Out:
#          Opening  Opening.1                 Title  \
# 0  J A N U A R Y          6                 M3GAN
# 1  J A N U A R Y          6           The Old Way
# 2  J A N U A R Y         11  The Devil Conspiracy
# 3  J A N U A R Y         13                 Plane
# 4  J A N U A R Y         13           House Party
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / A...
# 1                         Saban Films / Saturn Films
# 2                               Samuel Goldwyn Films
# 3  Lionsgate / MadRiver Pictures / Di Bonaventura...
# 4            Warner Bros. Pictures / New Line Cinema
#
#                                        Cast and crew Ref.  \
# 0  Gerard Johnstone (director); Akela Cooper (scr...  [3]
# 1  Brett Donowho (director); Carl W. Lucas (scree...  [4]
# 2  Nathan Frankowski (director); Ed Alan (screenp...  [5]
# 3  Jean-François Richet (director); Charles Cummi...  [6]
# 4  Calmatic (director); Jamal Olori, Stephen Glov...  [7]
#
#                                     genres
# 0                   Science Fiction Horror
# 1                            Western Drama
# 2  Horror Fantasy Science Fiction Thriller
# 3                Action Adventure Thriller
# 4                                   Comedy

# %%
df_2023 = df[['Title', 'Cast and crew', 'genres']]
df_2023.head()
# Out:
#                   Title                                      Cast and crew  \
# 0                 M3GAN  Gerard Johnstone (director); Akela Cooper (scr...
# 1           The Old Way  Brett Donowho (director); Carl W. Lucas (scree...
# 2  The Devil Conspiracy  Nathan Frankowski (director); Ed Alan (screenp...
# 3                 Plane  Jean-François Richet (director); Charles Cummi...
# 4           House Party  Calmatic (director); Jamal Olori, Stephen Glov...
#
#                                     genres
# 0                   Science Fiction Horror
# 1                            Western Drama
# 2  Horror Fantasy Science Fiction Thriller
# 3                Action Adventure Thriller
# 4                                   Comedy

# %%
df_2023['director_name'] = df_2023['Cast and crew'].apply(extract_director)
# Out:
# <ipython-input-70-0ccb3c7242b9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['director_name'] = df_2023['Cast and crew'].apply(extract_director)

# %%
df_2023['actor_1_name'] = df_2023['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-71-bcbd61cbd292>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['actor_1_name'] = df_2023['Cast and crew'].map(lambda x: get_actor1(x))

# %%
df_2023['actor_2_name'] = df_2023['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-72-5054af5e8e9b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['actor_2_name'] = df_2023['Cast and crew'].map(lambda x: get_actor2(x))

# %%
df_2023['actor_3_name'] = df_2023['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2023
# Out:
#                     Title                                      Cast and crew  \
# 0                   M3GAN  Gerard Johnstone (director); Akela Cooper (scr...
# 1             The Old Way  Brett Donowho (director); Carl W. Lucas (scree...
# 2    The Devil Conspiracy  Nathan Frankowski (director); Ed Alan (screenp...
# 3                   Plane  Jean-François Richet (director); Charles Cummi...
# 4             House Party  Calmatic (director); Jamal Olori, Stephen Glov...
# ..                    ...                                                ...
# 338                Memory  Michel Franco (director/screenplay); Jessica C...
# 339      The Color Purple  Blitz Bazawule (director), Marcus Gardley (scr...
# 340  The Boys in the Boat  George Clooney (director), Mark L. Smith (scre...
# 341               Ferrari  Michael Mann (director), Troy Kennedy Martin (...
# 342            Good Grief  Dan Levy (director/screenplay); Dan Levy, Ruth...
#
#                                       genres      director_name  \
# 0                     Science Fiction Horror   Gerard Johnstone
# 1                              Western Drama      Brett Donowho
# 2    Horror Fantasy Science Fiction Thriller  Nathan Frankowski
# 3                  Action Adventure Thriller         ois Richet
# 4                                     Comedy           Calmatic
# ..                                       ...                ...
# 338                    Action Thriller Crime      Michel Franco
# 339                                    Drama     Blitz Bazawule
# 340                            Drama History     George Clooney
# 341                            History Drama       Michael Mann
# 342                             Comedy Drama           Dan Levy
#
#          actor_1_name          actor_2_name      actor_3_name
# 0    Allison Williams         Violet McGraw       Amie Donald
# 1        Nicolas Cage  Ryan Kiera Armstrong               NaN
# 2     Alice Orr-Ewing             Joe Doyle      Eveline Hall
# 3       Gerard Butler           Mike Colter          Yoson An
# 4          Tosin Cole        Jacob Latimore      Karen Obilom
# ..                ...                   ...               ...
# 338  Jessica Chastain       Peter Sarsgaard     Merritt Wever
# 339  Fantasia Barrino      Taraji P. Henson   Danielle Brooks
# 340     Callum Turner         Joel Edgerton    Peter Guinness
# 341       Adam Driver         Penelope Cruz  Shailene Woodley
# 342          Dan Levy            Ruth Negga      Himesh Patel
#
# [343 rows x 7 columns]

# %%
df_2023 = df_2023.rename(columns={'Title':'movie_title'})

# %%
df_2023_new = df_2023.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
df_2023_new['actor_2_name'] = df_2023_new['actor_2_name'].replace(np.nan, 'unknown')
df_2023_new['actor_3_name'] = df_2023_new['actor_3_name'].replace(np.nan, 'unknown')

# %%
df_2023_new['movie_title'] = df_2023_new['movie_title'].str.lower()

# %%
df_2023_new['col_merge'] = df_2023_new['actor_1_name'] + ' ' + df_2023_new['actor_2_name'] + ' '+ df_2023_new['actor_3_name'] + ' '+ df_2023_new['director_name'] +' ' + df_2023_new['genres']
df_2023_new.head()
# Out:
#        director_name      actor_1_name          actor_2_name  actor_3_name  \
# 0   Gerard Johnstone  Allison Williams         Violet McGraw   Amie Donald
# 1      Brett Donowho      Nicolas Cage  Ryan Kiera Armstrong       unknown
# 2  Nathan Frankowski   Alice Orr-Ewing             Joe Doyle  Eveline Hall
# 3         ois Richet     Gerard Butler           Mike Colter      Yoson An
# 4           Calmatic        Tosin Cole        Jacob Latimore  Karen Obilom
#
#                                     genres           movie_title  \
# 0                   Science Fiction Horror                 m3gan
# 1                            Western Drama           the old way
# 2  Horror Fantasy Science Fiction Thriller  the devil conspiracy
# 3                Action Adventure Thriller                 plane
# 4                                   Comedy           house party
#
#                                            col_merge
# 0  Allison Williams Violet McGraw Amie Donald Ger...
# 1  Nicolas Cage Ryan Kiera Armstrong unknown Bret...
# 2  Alice Orr-Ewing Joe Doyle Eveline Hall Nathan ...
# 3  Gerard Butler Mike Colter Yoson An ois Richet ...
# 4  Tosin Cole Jacob Latimore Karen Obilom Calmati...

# %%
data_till_2023 = pd.concat([data_till_2022, df_2023_new], ignore_index=True)

# %%
data_till_2023.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# col_merge        0
# dtype: int64

# %% [markdown]
# # **Extracting features of 2024 movies from Wikipedia**

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2024"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
df.head()
# Out:
#      Opening              Title  \
# 0  January 2  The Mummy Murders
# 1  January 3      Self Reliance
# 2  January 4           DarkGame
# 3  January 5         Night Swim
# 4  January 5   He Went That Way
#
#                                   Production company  \
# 0                                  Gravitas Ventures
# 1  Neon, Hulu , MRC , Paramount Global Content Di...
# 2                                  Gravitas Ventures
# 3  Universal Pictures, Blumhouse Productions , At...
# 4  Vertical Entertainment, Mister Smith Entertain...
#
#                                        Cast and crew Ref.  Opening.1
# 0  Colin Bressler (director/screenplay); Will Don...  [3]        NaN
# 1  Jake Johnson (director/screenplay); Jake Johns...  [4]        NaN
# 2  Howard J. Ford (director); Gary Grant, Niall J...  [5]        NaN
# 3  Bryce McGuire (director/screenplay); Wyatt Rus...  [6]        NaN
# 4  Jeffrey Darling (director); Evan M. Wiener (sc...  [7]        NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df.head()
# Out:
# Error accessing movie ID for title 'The Geeks (Los Frikis)': getattr(): attribute name must be string
#      Opening              Title  \
# 0  January 2  The Mummy Murders
# 1  January 3      Self Reliance
# 2  January 4           DarkGame
# 3  January 5         Night Swim
# 4  January 5   He Went That Way
#
#                                   Production company  \
# 0                                  Gravitas Ventures
# 1  Neon, Hulu , MRC , Paramount Global Content Di...
# 2                                  Gravitas Ventures
# 3  Universal Pictures, Blumhouse Productions , At...
# 4  Vertical Entertainment, Mister Smith Entertain...
#
#                                        Cast and crew Ref.  Opening.1  \
# 0  Colin Bressler (director/screenplay); Will Don...  [3]        NaN
# 1  Jake Johnson (director/screenplay); Jake Johns...  [4]        NaN
# 2  Howard J. Ford (director); Gary Grant, Niall J...  [5]        NaN
# 3  Bryce McGuire (director/screenplay); Wyatt Rus...  [6]        NaN
# 4  Jeffrey Darling (director); Evan M. Wiener (sc...  [7]        NaN
#
#                  genres
# 0          Horror Crime
# 1       Comedy Thriller
# 2       Horror Thriller
# 3                Horror
# 4  Thriller Crime Drama

# %%
df_2024 = df[['Title', 'Cast and crew', 'genres']]
df_2024.head()
# Out:
#                Title                                      Cast and crew  \
# 0  The Mummy Murders  Colin Bressler (director/screenplay); Will Don...
# 1      Self Reliance  Jake Johnson (director/screenplay); Jake Johns...
# 2           DarkGame  Howard J. Ford (director); Gary Grant, Niall J...
# 3         Night Swim  Bryce McGuire (director/screenplay); Wyatt Rus...
# 4   He Went That Way  Jeffrey Darling (director); Evan M. Wiener (sc...
#
#                  genres
# 0          Horror Crime
# 1       Comedy Thriller
# 2       Horror Thriller
# 3                Horror
# 4  Thriller Crime Drama

# %%
df_2024
# Out:
#                       Title  \
# 0         The Mummy Murders
# 1             Self Reliance
# 2                  DarkGame
# 3                Night Swim
# 4          He Went That Way
# ..                      ...
# 469               Nosferatu
# 470      A Complete Unknown
# 471         The Fire Inside
# 472                Babygirl
# 473  The Geeks (Los Frikis)
#
#                                          Cast and crew                genres
# 0    Colin Bressler (director/screenplay); Will Don...          Horror Crime
# 1    Jake Johnson (director/screenplay); Jake Johns...       Comedy Thriller
# 2    Howard J. Ford (director); Gary Grant, Niall J...       Horror Thriller
# 3    Bryce McGuire (director/screenplay); Wyatt Rus...                Horror
# 4    Jeffrey Darling (director); Evan M. Wiener (sc...  Thriller Crime Drama
# ..                                                 ...                   ...
# 469  Robert Eggers (director/screenplay); Bill Skar...  Drama Fantasy Horror
# 470  James Mangold (director/screenplay); Jay Cocks...   Drama Music History
# 471  Rachel Morrison (director); Barry Jenkins (scr...                 Drama
# 472  Halina Reijn (director/screenplay); Nicole Kid...                 Drama
# 473  Michael Schwartz, Tyler Nilson (directors/scre...                   NaN
#
# [474 rows x 3 columns]

# %%
non_string_rows = df_2024[~df_2024['Cast and crew'].apply(lambda x: isinstance(x, str))]

# Print the rows
print(non_string_rows)
# Out:
#     Title Cast and crew       genres
# 233   NaN           NaN  Drama Crime

# %%
df_2024 = df_2024.drop(233) #Dropping row 233 as it was NaN

# %%
df_2024['director_name'] = df_2024['Cast and crew'].apply(extract_director)

# %%
df_2024['actor_1_name'] = df_2024['Cast and crew'].map(lambda x: get_actor1(x))

# %%
df_2024['actor_2_name'] = df_2024['Cast and crew'].map(lambda x: get_actor2(x))

# %%
df_2024['actor_3_name'] = df_2024['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2024
# Out:
#                       Title  \
# 0         The Mummy Murders
# 1             Self Reliance
# 2                  DarkGame
# 3                Night Swim
# 4          He Went That Way
# ..                      ...
# 469               Nosferatu
# 470      A Complete Unknown
# 471         The Fire Inside
# 472                Babygirl
# 473  The Geeks (Los Frikis)
#
#                                          Cast and crew                genres  \
# 0    Colin Bressler (director/screenplay); Will Don...          Horror Crime
# 1    Jake Johnson (director/screenplay); Jake Johns...       Comedy Thriller
# 2    Howard J. Ford (director); Gary Grant, Niall J...       Horror Thriller
# 3    Bryce McGuire (director/screenplay); Wyatt Rus...                Horror
# 4    Jeffrey Darling (director); Evan M. Wiener (sc...  Thriller Crime Drama
# ..                                                 ...                   ...
# 469  Robert Eggers (director/screenplay); Bill Skar...  Drama Fantasy Horror
# 470  James Mangold (director/screenplay); Jay Cocks...   Drama Music History
# 471  Rachel Morrison (director); Barry Jenkins (scr...                 Drama
# 472  Halina Reijn (director/screenplay); Nicole Kid...                 Drama
# 473  Michael Schwartz, Tyler Nilson (directors/scre...                   NaN
#
#        director_name            actor_1_name       actor_2_name  \
# 0     Colin Bressler  Leila Annastasia Scott   Jason Scarbrough
# 1       Jake Johnson            Jake Johnson      Anna Kendrick
# 2     Howard J. Ford             Ed Westwick  Andrew P. Stephen
# 3      Bryce McGuire           Wyatt Russell       Kerry Condon
# 4    Jeffrey Darling            Jacob Elordi     Zachary Quinto
# ..               ...                     ...                ...
# 469    Robert Eggers          Bill Skarsgård     Nicholas Hoult
# 470    James Mangold       Timothée Chalamet      Edward Norton
# 471  Rachel Morrison            Ryan Destiny  Brian Tyree Henry
# 472     Halina Reijn           Nicole Kidman   Harris Dickinson
# 473     Tyler Nilson           Héctor Medina       Adria Arjona
#
#           actor_3_name
# 0        Jeff Caperton
# 1      Natalie Morales
# 2    Natalya Tsvetkova
# 3      Amélie Hoeferle
# 4     Patrick J. Adams
# ..                 ...
# 469     Lily-Rose Depp
# 470       Elle Fanning
# 471         Judy Greer
# 472       Sophie Wilde
# 473  Eros de la Puente
#
# [473 rows x 7 columns]

# %%
df_2024 = df_2024.rename(columns={'Title':'movie_title'})

# %%
df_2024_new = df_2024.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
df_2024_new['actor_2_name'] = df_2024_new['actor_2_name'].replace(np.nan, 'unknown')
df_2024_new['actor_3_name'] = df_2024_new['actor_3_name'].replace(np.nan, 'unknown')

# %%
df_2024_new['movie_title'] = df_2024_new['movie_title'].str.lower()

# %%
df_2024_new['col_merge'] = df_2024_new['actor_1_name'] + ' ' + df_2024_new['actor_2_name'] + ' '+ df_2024_new['actor_3_name'] + ' '+ df_2024_new['director_name'] +' ' + df_2024_new['genres']
df_2024_new.head()
# Out:
#      director_name            actor_1_name       actor_2_name  \
# 0   Colin Bressler  Leila Annastasia Scott   Jason Scarbrough
# 1     Jake Johnson            Jake Johnson      Anna Kendrick
# 2   Howard J. Ford             Ed Westwick  Andrew P. Stephen
# 3    Bryce McGuire           Wyatt Russell       Kerry Condon
# 4  Jeffrey Darling            Jacob Elordi     Zachary Quinto
#
#         actor_3_name                genres        movie_title  \
# 0      Jeff Caperton          Horror Crime  the mummy murders
# 1    Natalie Morales       Comedy Thriller      self reliance
# 2  Natalya Tsvetkova       Horror Thriller           darkgame
# 3    Amélie Hoeferle                Horror         night swim
# 4   Patrick J. Adams  Thriller Crime Drama   he went that way
#
#                                            col_merge
# 0  Leila Annastasia Scott Jason Scarbrough Jeff C...
# 1  Jake Johnson Anna Kendrick Natalie Morales Jak...
# 2  Ed Westwick Andrew P. Stephen Natalya Tsvetkov...
# 3  Wyatt Russell Kerry Condon Amélie Hoeferle Bry...
# 4  Jacob Elordi Zachary Quinto Patrick J. Adams J...

# %%
data_till_2024 = pd.concat([data_till_2023, df_2024_new], ignore_index=True)

# %%
data_till_2024.isna().sum()
# Out:
# director_name    1
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           1
# movie_title      0
# col_merge        2
# dtype: int64

# %%
data_till_2024 = data_till_2024.dropna(how='any')

# %%
data_till_2024.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# col_merge        0
# dtype: int64

# %%
data_till_2024.to_csv('data_till_2024.csv', index=False)
